# %% [markdown]
# <a href="https://colab.research.google.com/github/ToluClassics/-FCCSUrveyform/blob/master/Classification%20on%20the%20MNISTdataset%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import fast ai library

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *
from fastai.metrics import error_rate

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.MNIST_SAMPLE);
path
# Out:
# PosixPath('/root/.fastai/data/mnist_sample')

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_sample/labels.csv'),
#  PosixPath('/root/.fastai/data/mnist_sample/train'),
#  PosixPath('/root/.fastai/data/mnist_sample/valid')]

# %%
(path/'train'/'7').ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_sample/train/7/17117.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/14138.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/47806.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/21405.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/40891.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/34161.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/32028.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/9263.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/1281.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/9548.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/23192.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/17533.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/2512.png'),
#  PosixPath('/root/.fastai/data/mnist_sample/train/7/26568.png'),
# ...
